# %%
import pandas as pd

# %%
tips = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/tips.csv')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info?

# %%
tips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.rename(columns={'total_bill': 'total'}, inplace=True)

# %%
tips.columns
# Out:
# Index(['total', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.rename(columns={'total': 'total_bill'}, inplace=True)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips[['smoker', 'sex']]
# Out:
#     smoker     sex
# 0       No  Female
# 1       No    Male
# 2       No    Male
# 3       No    Male
# 4       No  Female
# ..     ...     ...
# 239     No    Male
# 240    Yes  Female
# 241    Yes    Male
# 242     No    Male
# 243     No  Female
#
# [244 rows x 2 columns]

# %%
tips[tips['smoker'] == 'Yes']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
tips[(tips['smoker'] == 'Yes') & (tips['sex'] == 'Female')].head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73       25.28  5.00  Female    Yes  Sat  Dinner     2
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2
# 93       16.32  4.30  Female    Yes  Fri  Dinner     2

# %%
tips['total_bill'][(tips['smoker'] == 'Yes') & (tips['sex'] == 'Female')].head()
# Out:
# 67     3.07
# 72    26.86
# 73    25.28
# 92     5.75
# 93    16.32
# Name: total_bill, dtype: float64

# %%
tips[['total_bill', 'sex']].values
# Out:
# array([[16.99, 'Female'],
#        [10.34, 'Male'],
#        [21.01, 'Male'],
#        [23.68, 'Male'],
#        [24.59, 'Female'],
#        [25.29, 'Male'],
#        [8.77, 'Male'],
#        [26.88, 'Male'],
#        [15.04, 'Male'],
#        [14.78, 'Male'],
#        [10.27, 'Male'],
#        [35.26, 'Female'],
#        [15.42, 'Male'],
#        [18.43, 'Male'],
#        [14.83, 'Female'],
#        [21.58, 'Male'],
#        [10.33, 'Female'],
#        [16.29, 'Male'],
#        [16.97, 'Female'],
#        [20.65, 'Male'],
#        [17.92, 'Male'],
#        [20.29, 'Female'],
#        [15.77, 'Female'],
#        [39.42, 'Male'],
#        [19.82, 'Male'],
#        [17.81, 'Male'],
#        [13.37, 'Male'],
#        [12.69, 'Male'],
#        [21.7, 'Male'],
#        [19.65, 'Female'],
#        [9.55, 'Male'],
#        [18.35, 'Male'],
#        [15.06, 'Female'],
#        [20.69, 'Female'],
#        [17.78, 'Male'],
#        [24.06, 'Male'],
#        [16.31, 'Male'],
# ...

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %%
tips.sort_values(by=['total_bill', 'tip'], ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00  Female    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
tips.iloc[170,2] = 'Female'

# %%
tips.iloc[170,2]
# Out:
# 'Female'

# %%
tips.sort_values(by=['total_bill', 'tip'], ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00  Female    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]
